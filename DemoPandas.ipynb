# %%
# DemoPandas.ipynb
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#라인그래프 그리기
# x = np.arange(0, 10, 0.1)
# y = np.sin(x)
# plt.plot(x, y)
plt.plot(np.arange(10.1)) #해당 셀을 실행: shift + enter
